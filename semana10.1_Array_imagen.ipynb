# %%
#Imagenes con Numpy (arrays)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
imagen= Image.open(r'C:\Users\dg_su\OneDrive - Universidad Tecnologica del Peru\Estudios\Cursos\Analisis de Datos\Ciencia de Datos con Python IEEE AESS\codigo\archivos\satoru.jpg')

# %%
imagen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
type(imagen)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagen.size
# Out:
# (1280, 720)

# %%
array_imagen= np.asarray(imagen)

# %%
array_imagen
# Out:
# array([[[122, 145, 186],
#         [117, 140, 181],
#         [109, 132, 173],
#         ...,
#         [123, 150, 169],
#         [133, 160, 179],
#         [140, 167, 186]],
#
#        [[113, 136, 177],
#         [107, 130, 171],
#         [ 99, 122, 163],
#         ...,
#         [113, 140, 159],
#         [123, 150, 169],
#         [130, 157, 176]],
#
#        [[102, 125, 166],
#         [ 96, 119, 160],
#         [ 88, 111, 152],
#         ...,
#         [101, 128, 147],
#         [111, 138, 157],
#         [118, 145, 164]],
#
#        ...,
#
#        [[ 39,  69,  97],
#         [ 36,  66,  94],
#         [ 31,  61,  89],
#         ...,
#         [178, 179, 181],
#         [199, 200, 202],
#         [210, 211, 213]],
#
#        [[ 43,  73, 101],
#         [ 40,  70,  98],
#         [ 35,  65,  93],
#         ...,
#         [193, 194, 196],
#         [214, 215, 217],
#         [225, 226, 228]],
#
#        [[ 46,  76, 104],
#         [ 43,  73, 101],
#         [ 38,  68,  96],
# ...

# %%
plt.imshow(array_imagen)

# %%
array_imagen.shape #Formato RGB Rojo, verde y Azul
# Out:
# (720, 1280, 3)

# %%
array_imagen[:,:,2] #Color Rojo 0, verde 1 y Azul 2
# Out:
# array([[186, 181, 173, ..., 169, 179, 186],
#        [177, 171, 163, ..., 159, 169, 176],
#        [166, 160, 152, ..., 147, 157, 164],
#        ...,
#        [ 97,  94,  89, ..., 181, 202, 213],
#        [101,  98,  93, ..., 196, 217, 228],
#        [104, 101,  96, ..., 206, 227, 237]], dtype=uint8)

# %%
array_imagen
# Out:
# array([[[122, 145, 186],
#         [117, 140, 181],
#         [109, 132, 173],
#         ...,
#         [123, 150, 169],
#         [133, 160, 179],
#         [140, 167, 186]],
#
#        [[113, 136, 177],
#         [107, 130, 171],
#         [ 99, 122, 163],
#         ...,
#         [113, 140, 159],
#         [123, 150, 169],
#         [130, 157, 176]],
#
#        [[102, 125, 166],
#         [ 96, 119, 160],
#         [ 88, 111, 152],
#         ...,
#         [101, 128, 147],
#         [111, 138, 157],
#         [118, 145, 164]],
#
#        ...,
#
#        [[ 39,  69,  97],
#         [ 36,  66,  94],
#         [ 31,  61,  89],
#         ...,
#         [178, 179, 181],
#         [199, 200, 202],
#         [210, 211, 213]],
#
#        [[ 43,  73, 101],
#         [ 40,  70,  98],
#         [ 35,  65,  93],
#         ...,
#         [193, 194, 196],
#         [214, 215, 217],
#         [225, 226, 228]],
#
#        [[ 46,  76, 104],
#         [ 43,  73, 101],
#         [ 38,  68,  96],
# ...

# %%
pip install openCv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement openCv (from versions: none)
# ERROR: No matching distribution found for openCv
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

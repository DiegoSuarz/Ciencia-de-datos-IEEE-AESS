# %%
#pip install opencv-python

# %%
#pip install PACKAGE_NAME

# %%
#pip install --upgrade opencv-contrib-python

# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
imagen= cv2.imread('archivos\satoru.jpg')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_5280\4148992605.py:1: SyntaxWarning: invalid escape sequence '\s'
#   imagen= cv2.imread('archivos\satoru.jpg')

# %%
imagen2= cv2.imread('archivos\issac.jpg')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_5280\2584534395.py:1: SyntaxWarning: invalid escape sequence '\i'
#   imagen2= cv2.imread('archivos\issac.jpg')

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
imagen2.shape
# Out:
# (836, 1487, 3)

# %% [markdown]
# La representación del color es diferente En Open Es BGR (azul, verde y rojo) yn matplotlib es RGB

# %%
plt.imshow(imagen) #La representación del color es diferente En Open Es BGR (azul, verde y rojo) yn matplotlib es RGB

# %%
plt.imshow(imagen2) #La representación del color es diferente En Open Es BGR (azul, verde y rojo) yn matplotlib es RGB

# %%
imagen= cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# %%
imagen2= cv2.cvtColor(imagen2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen2)

# %%
plt.imshow(imagen)

# %%
imagen_blanco_negro = cv2.imread('archivos\satoru.jpg',  cv2.IMREAD_GRAYSCALE)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_5280\3994995077.py:1: SyntaxWarning: invalid escape sequence '\s'
#   imagen_blanco_negro = cv2.imread('archivos\satoru.jpg',  cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagen_blanco_negro, cmap='gray')

# %%
#Manipulación de imagenes

# %%
imagen= cv2.imread('archivos\satoru.jpg')
imagen= cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_5280\833222887.py:1: SyntaxWarning: invalid escape sequence '\s'
#   imagen= cv2.imread('archivos\satoru.jpg')

# %%
plt.imshow(imagen)

# %%
imagen.shape
# Out:
# (720, 1280, 3)

# %%
imagen2 = cv2.resize(imagen, (600,500)) #ancho, altura

# %%
plt.imshow(imagen2)

# %%
#tambien se puede hacer por porcentaje
ratio_ancho = 0.5 #la mitad
ratio_alto = 0.5 #la mitad

# %%
imagen3 = cv2.resize(imagen, (0,0),imagen,ratio_ancho,ratio_alto)

# %%
plt.imshow(imagen3)

# %%
imagen4 = cv2.flip(imagen, 1) #modo espejo

# %%
plt.imshow(imagen4)

# %%
imagen5 = cv2.flip(imagen, 0) #invertir

# %%
plt.imshow(imagen5)

# %%
#Para guardarlo
imagen5 = cv2.cvtColor(imagen5, cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite('archivos\satorualreves.jpg', imagen5)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_5280\3469620901.py:1: SyntaxWarning: invalid escape sequence '\s'
#   cv2.imwrite('archivos\satorualreves.jpg', imagen5)
# True

# %% [markdown]
# # Dibujar figuras dentro de una imagen

# %%
imagen6 = np.zeros(shape=(500,500,3), dtype= np.int16)

# %%
imagen6.shape
# Out:
# (500, 500, 3)

# %%
plt.imshow(imagen6)

# %%
cv2.rectangle(imagen6, pt1=(20,20), pt2=(100,100), color=(255,120,0), thickness=10)  
#pl1 esquina superior derecha y pl2 esquina inferior derecha y thickness el grosor
#RGB ROJO=(255,0,0), VERDE=(0,255,0)
plt.imshow(imagen6)

# %%
cv2.circle(imagen6, center=(250,250), radius=100, color=(0,255,0),thickness=10)
plt.imshow(imagen6)

# %%
cv2.line(imagen6, pt1=(0,400), pt2=(500,400), color=(0,0,255), thickness=10 )
plt.imshow(imagen6)

# %% [markdown]
# # Escribimos texto en la imagen

# %%
imagen7 = np.zeros(shape=(500,500,3), dtype= np.int16)

# %%
imagen7.shape
# Out:
# (500, 500, 3)

# %%
plt.imshow(imagen7)

# %%
fuente = cv2.FONT_HERSHEY_SCRIPT_COMPLEX #fuente
cv2.putText(imagen7, text='SATORU', org=(20,100), fontFace=fuente, fontScale=3, color=(0,255,0), thickness=4, lineType=cv2.LINE_8)
plt.imshow(imagen7)

# %% [markdown]
# # CREACIÓN DE UN POLIGONO MARCANDO LOS VERTICES

# %%
vertices = np.array([ [100,300], [300,200], [400,400], [200,400] ], dtype=np.int32)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
vertices
# Out:
# array([[100, 300],
#        [300, 200],
#        [400, 400],
#        [200, 400]])

# %%
#añadimos una nueva dimensión para poder construir nuestro poligono
puntos = vertices.reshape(-1,1,2)
puntos.shape
# Out:
# (4, 1, 2)

# %%
puntos
# Out:
# array([[[100, 300]],
#
#        [[300, 200]],
#
#        [[400, 400]],
#
#        [[200, 400]]])

# %%
cv2.polylines(imagen7, [puntos], isClosed=True, color=(255,255,255), thickness=5) 
plt.imshow(imagen7)

# %% [markdown]
# # Dibujar con el ratón en una imagen

# %%
# Definimos la función para dibujar con el ratón
def dibujar(event, x, y, etiquetas, parametros):
    if event == cv2.EVENT_LBUTTONDOWN:  # Cada vez que se presione el botón izquierdo del ratón
        # Dibuja un círculo en la posición (x, y) con radio 50 y color azul
        cv2.circle(imagen8, (x, y), 50, (255, 0, 0), -1)

# Conectamos la imagen con la función dibujar
cv2.namedWindow('mi_imagen8')  # Crea una ventana llamada 'mi_imagen8'
cv2.setMouseCallback('mi_imagen8', dibujar)  # Asocia la función 'dibujar' con los eventos del ratón en la ventana 'mi_imagen8'

# Creamos una imagen en negro donde vamos a pintar
imagen8 = np.zeros((500, 500, 3), np.uint8)

# Bucle principal para mostrar la imagen y detectar eventos del ratón
while True:
    cv2.imshow('mi_imagen8', imagen8)  # Muestra la imagen en la ventana
    if cv2.waitKey(10) & 0xFF == 27:  # Espera 10 ms y verifica si se ha presionado la tecla 'Esc' (código ASCII 27) para cerrar
        break
    if cv2.getWindowProperty('mi_imagen8', cv2.WND_PROP_VISIBLE) < 1:  # Verifica si la ventana ha sido cerrada
        break

# Destruye todas las ventanas creadas por OpenCV
cv2.destroyAllWindows()

# %% [markdown]
# # Dibujar arrastrando el ratón sobre una imagen

# %%
# Variables globales para almacenar el estado del dibujo y las coordenadas
dibujando = False
valorx = 0
valory = 0

# Definimos la función para dibujar
def dibujar(event, x, y, etiquetas, parametros):
    global dibujando, valorx, valory
    # Cuando se presiona el botón izquierdo del ratón
    if event == cv2.EVENT_LBUTTONDOWN:
        dibujando = True  # Comienza a dibujar
        valorx = x  # Guarda la coordenada x inicial
        valory = y  # Guarda la coordenada y inicial
    # Mientras se mueve el ratón con el botón izquierdo presionado
    elif event == cv2.EVENT_MOUSEMOVE:
        if dibujando == True:
            # Dibuja un rectángulo desde el punto inicial hasta el punto actual
            cv2.rectangle(imagen8, (valorx, valory), (x, y), (255, 0, 0), -1)
    # Cuando se suelta el botón izquierdo del ratón
    elif event == cv2.EVENT_LBUTTONUP:
        dibujando = False  # Termina de dibujar
        # Dibuja el rectángulo final
        cv2.rectangle(imagen8, (valorx, valory), (x, y), (255, 0, 0), -1)

# Conectamos la ventana de la imagen con la función dibujar
cv2.namedWindow('mi_imagen9')
cv2.setMouseCallback('mi_imagen9', dibujar)

# Creamos una imagen en negro donde vamos a pintar
imagen8 = np.zeros((500, 500, 3), np.uint8)

# Bucle principal para mostrar la imagen y detectar eventos del ratón
while True:
    cv2.imshow('mi_imagen9', imagen8)
    # Espera 10 ms y verifica si se ha presionado la tecla 'Esc' (código ASCII 27) para cerrar
    if cv2.waitKey(10) & 0xFF == 27:
        break
    # Verifica si la ventana ha sido cerrada
    if cv2.getWindowProperty('mi_imagen9', cv2.WND_PROP_VISIBLE) < 1:
        break

# Destruye todas las ventanas creadas por OpenCV
cv2.destroyAllWindows()
